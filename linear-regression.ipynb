# %% [markdown]
# # Linear Regression

# %% [markdown]
# Load the toy polynomial dataset

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

from utils.data_utils import get_poly_observation_data, get_poly_plot_data

X, y = get_poly_observation_data()
plot_X, plot_y = get_poly_plot_data()
plt.scatter(X, y, label='observation')
plt.plot(plot_X, plot_y, label='denoised truth', color='green')
plt.legend()
plt.show()
