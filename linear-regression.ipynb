# %% [markdown]
# # Linear Regression

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

from utils.data_utils import get_poly_observation_data, get_poly_plot_data, get_cluster_toy_data

X, y = get_poly_observation_data()
plot_X, plot_y = get_poly_plot_data()
plt.scatter(X, y, label='observation')
plt.plot(plot_X, plot_y, label='denoised truth', color='green')
plt.legend()
plt.show()

# %% [markdown]
# # Clustering data

# %%
from utils.visualize_utils import plot_cluster_data

cluster_data_list, label_set =  get_cluster_toy_data()

for points, labels in cluster_data_list:
    plot_cluster_data(points, labels)
plt.show()
